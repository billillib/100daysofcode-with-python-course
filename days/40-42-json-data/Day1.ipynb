# %%
import requests 
import json
from pprint import pprint
from api_keys import imdb_key

# %%
url = f"http://www.omdbapi.com/?apikey={imdb_key}&t=Blazing+Saddles"
response = requests.get(url)
data = json.loads(response.text)

# %%
print(data)
# Out:
# {'Title': 'Blazing Saddles', 'Year': '1974', 'Rated': 'R', 'Released': '07 Feb 1974', 'Runtime': '93 min', 'Genre': 'Comedy, Western', 'Director': 'Mel Brooks', 'Writer': 'Mel Brooks (screenplay), Norman Steinberg (screenplay), Andrew Bergman (screenplay), Richard Pryor (screenplay), Alan Uger (screenplay), Andrew Bergman (story)', 'Actors': 'Cleavon Little, Gene Wilder, Slim Pickens, Harvey Korman', 'Plot': 'In order to ruin a western town, a corrupt politician appoints a black Sheriff, who promptly becomes his most formidable adversary.', 'Language': 'English, Yiddish, German', 'Country': 'USA', 'Awards': 'Nominated for 3 Oscars. Another 3 wins & 2 nominations.', 'Poster': 'https://m.media-amazon.com/images/M/MV5BZGZmMWE1MDYtNzAyNC00MDMzLTgzZjQtNTQ5NjYzN2E4MzkzXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '91%'}, {'Source': 'Metacritic', 'Value': '73/100'}], 'Metascore': '73'
# ...

# %%
for item in data['Ratings']:
    pprint(item["Source"])
# Out:
# 'Internet Movie Database'
# 'Rotten Tomatoes'
# 'Metacritic'

# %%
with open('code/mount-data.json','r') as f:
    data = json.load(f)

# %%
for i in data['mounts']['collected']:
    pprint(i['name'])
# Out:
# 'Albino Drake'
# 'Amber Scorpion'
# 'Argent Hippogryph'
# 'Argent Warhorse'
# 'Armored Blue Dragonhawk'
# 'Armored Brown Bear'
# 'Armored Snowy Gryphon'
# "Ashes of Al'ar"
# 'Azure Cloud Serpent'
# 'Azure Netherwing Drake'
# 'Azure Riding Crane'
# 'Azure Water Strider'
# 'Black Battlestrider'
# 'Black Drake'
# 'Black Primal Raptor'
# 'Black Riding Goat'
# 'Black War Bear'
# 'Black War Elekk'
# 'Black War Mammoth'
# 'Black War Ram'
# 'Black War Steed'
# 'Black War Tiger'
# 'Blonde Riding Yak'
# 'Bloodbathed Frostbrood Vanquisher'
# 'Blue Dragonhawk'
# 'Blue Drake'
# 'Blue Riding Nether Ray'
# 'Bronze Drake'
# 'Brown Riding Camel'
# 'Brown Riding Goat'
# 'Celestial Steed'
# 'Cenarion War Hippogryph'
# 'Coalfist Gronnling'
# 'Cobalt Netherwing Drake'
# 'Cobalt Riding Talbuk'
# 'Cobalt War Talbuk'
# 'Core Hound'
# 'Corrupted Dreadwing'
# 'Dark Phoenix'
# 'Dark Riding Talbuk'
# 'Dark War Talbuk'
# 'Darkmoon Dancing Bear'
# 'Darkwater Skate'
# 'Darnassian Nightsaber'
# ...
